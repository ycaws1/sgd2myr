# %%
import requests
response = requests.get(
    "https://www.google.com/finance/quote/SGD-MYR",
)
text = response.text

# %%
re.findall('SGD/MYR ', text)
# Out:
# ['SGD/MYR ', 'SGD/MYR ', 'SGD/MYR ']
